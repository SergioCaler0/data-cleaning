# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
# !ls
# Out:
# attacks.csv  main.py  notebook.ipynb  README.md

# %%
pd.set_option("display.max_columns", 120)

# %%
data= pd.read_csv("../data-cleaning/attacks.csv", encoding='Windows-1252' )

# %%
data.head(200)
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ..            ...          ...     ...         ...        ...
# 195  2016.12.11.a  11-Dec-2016  2016.0     Invalid        USA
# 196    2016.12.06  06-Dec-2016  2016.0    Provoked  AUSTRALIA
# 197    2016.12.01  01-Dec-2016  2016.0  Unprovoked  AUSTRALIA
# 198    2016.11.28  28-Nov-2016  2016.0    Provoked  AUSTRALIA
# 199    2016.11.14  14-Nov-2016  2016.0  Unprovoked        USA
#
#                 Area                          Location      Activity  \
# 0         California       Oceanside, San Diego County      Paddling
# 1            Georgia    St. Simon Island, Glynn County      Standing
# ...

# %%
data.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
data.sample(30)
# Out:
#         Case Number         Date    Year        Type       Country  \
# 25018           NaN          NaN     NaN         NaN           NaN
# 20300           NaN          NaN     NaN         NaN           NaN
# 24323           NaN          NaN     NaN         NaN           NaN
# 9880            NaN          NaN     NaN         NaN           NaN
# 16277           NaN          NaN     NaN         NaN           NaN
# 7902              0          NaN     NaN         NaN           NaN
# 10410           NaN          NaN     NaN         NaN           NaN
# 2567     1992.01.23  23-Jan-1992  1992.0  Unprovoked  SOUTH AFRICA
# 17130           NaN          NaN     NaN         NaN           NaN
# 2539     1992.08.21  21-Aug-1992  1992.0     Invalid           USA
# 24889           NaN          NaN     NaN         NaN           NaN
# 15317           NaN          NaN     NaN         NaN           NaN
# 5711   1890.00.00.a     Ca. 1890  1890.0  Unprovoked  SOUTH AFRICA
# ...

# %%
to_drop = ['Unnamed: 22', 'Unnamed: 23']
data.drop(to_drop, inplace=True, axis=1)

# %%
data.sample(3)
# Out:
#       Case Number         Date    Year        Type    Country  \
# 1248   2008.06.20  20-Jun-2008  2008.0  Unprovoked        USA
# 5441   1907.12.21  21-Dec-1907  1907.0  Unprovoked  AUSTRALIA
# 16595         NaN          NaN     NaN         NaN        NaN
#
#                   Area                                         Location  \
# 1248           Florida                  Fernandina Beach, Nassau County
# 5441   New South Wales  Middle Harbour, Sugarloaf Bay, Sydney (Estuary)
# 16595              NaN                                              NaN
#
#       Activity             Name Sex   Age                           Injury  \
# 1248    Wading  Jennifer Cation    F   35  Lacerations to lower right calf
# 5441   Bathing      Henry Jones    M  NaN                            FATAL
# 16595      NaN              NaN  NaN  NaN                              NaN
#
#       Fatal (Y/N)   Time    Species   \
# 1248            N  11h10         NaN
# 5441            Y    NaN  Bull shark
# ...

# %%
data['href']
# Out:
# 0        http://sharkattackfile.net/spreadsheets/pdf_di...
# 1        http://sharkattackfile.net/spreadsheets/pdf_di...
# 2        http://sharkattackfile.net/spreadsheets/pdf_di...
# 3        http://sharkattackfile.net/spreadsheets/pdf_di...
# 4        http://sharkattackfile.net/spreadsheets/pdf_di...
#                                ...
# 25718                                                  NaN
# 25719                                                  NaN
# 25720                                                  NaN
# 25721                                                  NaN
# 25722                                                  NaN
# Name: href, Length: 25723, dtype: object

# %%
to_drop = ['href', 'href formula']
data.drop(to_drop, inplace=True, axis=1)
# he borrado las columnas porque los enlaces no tenian contenido y el resto de filas eran nan

# %%
data
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 25718         NaN          NaN     NaN         NaN        NaN
# 25719         NaN          NaN     NaN         NaN        NaN
# 25720         NaN          NaN     NaN         NaN        NaN
# 25721         NaN          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
data.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# Case Number.1              object
# Case Number.2              object
# original order            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Case Number               17021
# Date                      19421
# Year                      19423
# Type                      19425
# Country                   19471
# Area                      19876
# Location                  19961
# Activity                  19965
# Name                      19631
# Sex                       19986
# Age                       22252
# Injury                    19449
# Fatal (Y/N)               19960
# Time                      22775
# Species                   22259
# Investigator or Source    19438
# pdf                       19421
# Case Number.1             19421
# Case Number.2             19421
# original order            19414
# dtype: int64

# %%
data.fillna(df.filter(like='20').quantile(.8, axis = 1), axis=0, inplace=True)

# %%
df.Country
# Out:
# 0              USA
# 1              USA
# 2              USA
# 3        AUSTRALIA
# 4           MEXICO
#            ...
# 25718          NaN
# 25719          NaN
# 25720          NaN
# 25721          NaN
# 25722          NaN
# Name: Country, Length: 25723, dtype: object
